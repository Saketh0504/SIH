# %%
import pandas as pd
import numpy as np
import random
from sklearn.tree import DecisionTreeClassifier
train=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Hatstatic.xlsx")
train.head()
xtrain=train.drop(['Carrer Options'],axis=1)
ytrain=train['Carrer Options']
ytrain=ytrain.astype(object)
train1=pd.get_dummies(ytrain)
l=[]
s=['Computer skills','Research','Clerical Skills','Problem sloving','Analytical skills','Business skills',
'Decision making skills','Creativity','Reading','Artistic skills','Designing skills','Music','Teamwork',
'Communication skills','Innovative','Leadership','Electrical Skills','logical thinking','Helping','Teaching','Listening',
   'Programming Skills','Mathematic skills','Medical skills','Civil skills','Mechanical skills','Emotional Intellegence']
for i in range(27):
               l.append(int(input(f'Rate your skill for '+s[i]+ " : ")))
test=pd.DataFrame(data=l,index=s)
test1=test.transpose()
test1.head()
dtc=DecisionTreeClassifier(max_depth=4,random_state=0)
dtc.fit(xtrain,ytrain)
pred=dtc.predict(test1)
print("Your personality aligns well with: "+pred[0])
if(pred[0]=='Science'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Science.xlsx")
    x1=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i1 in x1:
        print(i1)
elif(pred[0]=='Engineering and technology'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Enginner.xlsx")
    x2=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i2 in x2:
        print(i2)
elif(pred[0]=='Mathematics'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Math.xlsx")
    x3=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:') 
    for i3 in x3:
        print(i3)
elif(pred[0]=='Business and Management'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Management.xlsx")
    print("You have risk taking capability")
    x4=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i4 in x4:
        print(i4)
elif(pred[0]=='Healthcare and medicine'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/health and medicine.xlsx")
    x5=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i5 in x5:
        print(i5)
elif(pred[0]=='Arts and humanities'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/Arts and Humanities.xlsx")
    x6=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i6 in x6:
        print(i6)
elif(pred[0]=='Social Sciences and education'):
    df=pd.read_excel("C:/Users/SAKETHBGS/OneDrive/Documents/SIH/social science.xlsx")
    x7=random.sample(df['JOBS'].tolist(),k=3)
    print('The suitable jobs in this domain may be:')
    for i7 in x7:
        print(i7)
# Out:
# Rate your skill for Computer skills : 6
# Rate your skill for Research : 7
# Rate your skill for Clerical Skills : 6
# Rate your skill for Problem sloving : 8
# Rate your skill for Analytical skills : 8
# Rate your skill for Business skills : 9
# Rate your skill for Decision making skills : 9
# Rate your skill for Creativity : 7
# Rate your skill for Reading : 1
# Rate your skill for Artistic skills : 2
# Rate your skill for Designing skills : 7
# Rate your skill for Music : 1
# Rate your skill for Teamwork : 7
# Rate your skill for Communication skills : 8
# Rate your skill for Innovative : 8
# Rate your skill for Leadership : 9
# Rate your skill for Electrical Skills : 2
# Rate your skill for logical thinking : 7
# Rate your skill for Helping : 5
# Rate your skill for Teaching : 4
# Rate your skill for Listening : 7
# Rate your skill for Programming Skills : 4
# Rate your skill for Mathematic skills : 3
# Rate your skill for Medical skills : 2
# ...
